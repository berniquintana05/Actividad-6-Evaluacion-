# %% [markdown]
# ## Actividad 6

# %% [markdown]
# Bernardo Quintana López A01658064

# %% [markdown]
# **Importar librerías**

# %%
import funciones as fn
import pandas as pd

# %% [markdown]
# **Agregar archivo de país**

# %%
Londres = pd.read_csv('Inglaterra.csv')
Londres.head()
# Out:
#         id last_scraped       source  host_id host_name host_since  \
# 0  56229.0     12/12/24  city scrape   216660     Boris   29/08/10
# 1  62970.0     12/12/24  city scrape   336059    Thomas   05/01/11
# 2  63948.0     12/12/24  city scrape   216660     Boris   29/08/10
# 3  66772.0     11/12/24  city scrape   216660     Boris   29/08/10
# 4  69198.0     11/12/24  city scrape   345886      Alda   13/01/11
#
#               host_location host_is_superhost host_neighbourhood  \
# 0    London, United Kingdom                 f        Hammersmith
# 1  Hamilton Parish, Bermuda               NaN          Mid-Beach
# 2    London, United Kingdom                 f        Hammersmith
# 3    London, United Kingdom                 f        Hammersmith
# 4    London, United Kingdom                 f                NaN
#
#    host_total_listings_count  ... review_scores_cleanliness  \
# 0                       11.0  ...                      4.67
# ...

# %% [markdown]
# **Función 1**

# %%
# Cargar el archivo
df = fn.datos('Inglaterra.csv')

# %% [markdown]
# **Función 2**

# %%
# Sustituir valores nulos
df = fn.nulos(df)

# %% [markdown]
# **Función 3**

# %%
#Identificar nulos 
nulos = fn.find_nulos(df)
print("Nulos por columna:", nulos["nulos_por_columna"])
print("Nulos totales:", nulos["nulos_totales"])
# Out:
# Nulos por columna: id                                              0
# last_scraped                                    0
# source                                          0
# host_id                                         0
# host_name                                       0
# host_since                                      0
# host_location                                   0
# host_is_superhost                               0
# host_neighbourhood                              0
# host_total_listings_count                       0
# host_has_profile_pic                            0
# host_identity_verified                          0
# neighbourhood                                   0
# property_type                                   0
# room_type                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# ...

# %% [markdown]
# **Función 4**

# %%
df_final = fn.atipicos(df)
# Out:
# Límite superior permitido: id                                              2.750000e+18
# host_id                                         8.591024e+08
# host_total_listings_count                       2.850000e+01
# accommodates                                    7.000000e+00
# bathrooms                                       1.881200e+00
# bedrooms                                        6.000000e+00
# beds                                            3.500000e+00
# price                                           2.665000e+02
# minimum_nights                                  8.500000e+00
# maximum_nights                                  2.722500e+03
# minimum_minimum_nights                          6.000000e+00
# maximum_minimum_nights                          9.500000e+00
# minimum_maximum_nights                          2.677500e+03
# maximum_maximum_nights                          2.664000e+03
# minimum_nights_avg_ntm                          9.250000e+00
# ...

# %% [markdown]
# **Resultado final**

# %%
df_final
# Out:
#       last_scraped       source   host_name host_since  \
# 0         12/12/24  city scrape       Boris   29/08/10
# 1         12/12/24  city scrape      Thomas   05/01/11
# 2         12/12/24  city scrape       Boris   29/08/10
# 3         11/12/24  city scrape       Boris   29/08/10
# 4         11/12/24  city scrape        Alda   13/01/11
# ...            ...          ...         ...        ...
# 95139     12/12/24  city scrape  Anastasiia   15/02/22
# 95140     11/12/24  city scrape       Susan   09/12/15
# 95141     12/12/24  city scrape       Steve   22/05/17
# 95142     11/12/24  city scrape      Ursula   31/03/19
# 95143     11/12/24  city scrape      Chione   09/05/16
#
#                   host_location      host_is_superhost     host_neighbourhood  \
# 0        London, United Kingdom                      f            Hammersmith
# 1      Hamilton Parish, Bermuda  Este_es_un_valor_nulo              Mid-Beach
# ...
